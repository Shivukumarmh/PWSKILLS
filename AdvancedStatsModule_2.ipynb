# %% [markdown]
# #Statistics Advance Part 1(Assignment Questions)
# ##    Theory
#
# 1. What is a random variable in probability theory?
#   - In probability theory, a random variable is a function that assigns numerical values to the outcomes of a random experiment. It provides a way to quantify uncertainty by mapping outcomes from a sample space to real numbers.
#
# 2. What are the types of random variables?
#   -  Discrete Random Variable
#   -  Continuous Random Variable
#
# 3.  What is the difference between discrete and continuous distributions?
#   - Discrete Distributions: It takes only the whole number as the assigned value on the number line.
#   - Continuous Distribution: It takes every number on the number line as the value.
#
# 4.  What are probability distribution functions (PDF)?
#   - A Probability Distribution Function (PDF) refers to a function that describes the likelihood of different outcomes of a random variable. The type of PDF depends on whether the random variable is discrete or continuous.
#
# 5.  How do cumulative distribution functions (CDF) differ from probability distribution functions (PDF)?
#   - CDF gives the summation of value till that point whereas the PDF give the value of that point only.
#
# 6.  What is a discrete uniform distribution ?
#   - A Discrete Uniform Distribution is a probability distribution where a finite number of outcomes are equally likely. Each possible value of the random variable has the same probability.
#
# 7.  What are the key properties of a Bernoulli distribution?
#   - It has only 2 possible outcomes one is success with the probability p and the other is failure with probability 1-p.
#
# 8.  What is the binomial distribution, and how is it used in probability?
#   - The Binomial Distribution is a discrete probability distribution that models the number of successes in a fixed number of independent Bernoulli trials, where each trial has only two possible outcomes.
#
# 9.  What is the Poisson distribution and where is it applied?
#   - The Poisson distribution is a discrete probability distribution that models the number of times an event occurs in a fixed interval of time or space, given that the events occur independently and at a constant average rate.
#
# 10.  What is a continuous uniform distribution?
#   - The continuous uniform distribution is a probability distribution in which all outcomes within a given range are equally likely. It is defined over a continuous interval [a,b], meaning that any value in this range has an equal probability of occurring.
#
# 11.  What are the characteristics of a normal distribution?
#   - The normal distribution (also called the Gaussian distribution) is a continuous probability distribution that is symmetric around its mean. It is one of the most important probability distributions in statistics and machine learning.
#
# 12. What is the standard normal distribution, and why is it important?
#   - It normal distribution with the mean = 0 and standard deviation = 1. It is important as it forms a common ground to compare various values.
#
# 13. What is the Central Limit Theorem (CLT), and why is it critical in statistics?
#   - When we take a large number of random samples from any population (regardless of its original distribution), the distribution of the sample means will approach a normal distribution as the sample size increases.
#   - Basically the sample mean follows a normal distribution as n increases.
#
# 14.  How does the Central Limit Theorem relate to the normal distribution?
#   - CLT shows that, regardless of the original population’s distribution, the sampling distribution of the sample mean will be approximately normal if the sample size is sufficiently large.
#
# 15. What is the application of Z statistics in hypothesis testing?
#   - It  is used in hypothesis testing when we want to determine whether a sample mean significantly differs from a known population mean.
#   - Used when:
#       - When we know the standard deviation of the population.
#       - When the sample size is greater than 30,ensuring normality by the Central Limit Theorem.
#
# 16. How do you calculate a Z-score, and what does it represent?
#   - It measures how far a data point is from the mean, in terms of standard deviations. It tells us how unusual or typical a value is within a dataset.
#
# 17. What are point estimates and interval estimates in statistics?
#   - A point estimate is a single value used to approximate a population parameter. It provides an exact estimate based on sample data.
#   - An interval estimate provides a range of values within which the population parameter is likely to lie. It is more reliable than a point estimate because it accounts for variability and uncertainty.
#
# 18.  What is the significance of confidence intervals in statistical analysis?
#   - It increases the confidence of the estimate.
#
# 19. What is the relationship between a Z-score and a confidence interval?
#   - The Z-score determines the confidence level of an interval estimate.
#   - A larger Z-score leads to a wider confidence interval.
#
# 20.  How are Z-scores used to compare different distributions?
#   - It is used to standardize values from different distributions, allowing for meaningful comparisons. By converting raw values into Z-scores, we can compare data from distributions with different means and standard deviations.
#
# 21. What are the assumptions for applying the Central Limit Theorem?
#   - Sample Size Should Be Large
#   - Finite Variance
#   - Random Sampling and Independent Observations.
#
# 22. What is the concept of expected value in a probability distribution?
#   - It is the mean of the sample for a given population.It represents the theoretical mean of the distribution.
#
# 23. How does a probability distribution relate to the expected outcome of a random variable?
#   - The expected value E(X) is calculated using the probabilities and possible values of a random variable.

# %% [markdown]
# #Practical

# %%
#1. Write a Python program to generate a random variable and display its value
import numpy as np
np.random.random()
# Out:
# 0.8165949036701226

# %%
#2. Generate a discrete uniform distribution using Python and plot the probability mass function (PMF)
import scipy.stats as stats
import matplotlib.pyplot as plt
import numpy as np

# Define the parameters of the distribution
low = 1   # Minimum outcome
high = 6  # Maximum outcome

# Create a discrete uniform distribution instance
dist = stats.randint(low, high + 1)

# Generate all possible outcomes
x = np.arange(low, high + 1)

# Calculate the PMF for each outcome
pmf = dist.pmf(x)

# Plot the PMF using a bar chart
plt.bar(x, pmf)
plt.xticks(x)
plt.title('PMF of a Discrete Uniform Distribution ({} to {})'.format(low, high))
plt.xlabel('Outcome')
plt.ylabel('Probability')
plt.show()

# %%
#3. Write a Python function to calculate the probability distribution function (PDF) of a Bernoulli distribution
def bernoulli_pmf(x, p):
    if x not in [0, 1]:
        raise ValueError("x must be 0 or 1 for a Bernoulli distribution.")
    if not (0 <= p <= 1):
        raise ValueError("p must be between 0 and 1.")

    return (p ** x) * ((1 - p) ** (1 - x))

# Example usage
p = 0.7  # Probability of success
print(f"P(X=0) = {bernoulli_pmf(0, p)}")
print(f"P(X=1) = {bernoulli_pmf(1, p)}")
# Out:
# P(X=0) = 0.30000000000000004
# P(X=1) = 0.7

# %%
#4. Write a Python script to simulate a binomial distribution with n=10 and p=0.5, then plot its histogram
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import binom

n=10
p=0.5
size=1000

samples = np.random.binomial(n, p, size)
plt.figure(figsize=(8, 5))
plt.hist(samples, bins=np.arange(n+2)-0.5, density=True, alpha=0.7, color='blue', edgecolor='black', label="Simulated Data")
plt.show()

# %%
#5. Create a Poisson distribution and visualize it using Python
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import poisson


λ = 5


x = np.arange(0, 15)  # Range of values to consider
pmf = poisson.pmf(x, λ)  # Compute PMF values


plt.figure()
plt.bar(x, pmf, width=0.6, color='blue', alpha=0.7, edgecolor='black', label=f'Poisson PMF (λ={λ})')


plt.xlabel('Number of Events (k)')
plt.ylabel('Probability')
plt.title('Poisson Distribution PMF')

plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()

# %%
#6.  Write a Python program to calculate and plot the cumulative distribution function (CDF) of a discrete uniform distribution
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import randint


a, b = 1, 6
dist = randint(a, b + 1)


x = np.arange(a, b + 1)
print(x)
cdf = dist.cdf(x)

# Plot the CDF

plt.step(x, cdf, where='mid', color='blue', linewidth=2, label="CDF")  # Step plot for discrete values


# Labels and title
plt.xlabel('Random Variable (X)')
plt.ylabel('Cumulative Probability')
plt.title('Cumulative Distribution Function (CDF) of Discrete Uniform Distribution')

plt.show()
# Out:
# [1 2 3 4 5 6]

# %%
#7. Generate a continuous uniform distribution using NumPy and visualize it
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import uniform


a, b = 2, 8


size = 10000
samples = np.random.uniform(a, b, size)


plt.hist(samples, bins=30, density=True, alpha=0.7, color='green', edgecolor='black', label="Simulated Data")


x = np.linspace(a, b, 1000)
pdf = uniform.pdf(x, a, b-a)
plt.plot(x, pdf, 'r-', lw=2, label="Theoretical PDF")

# Labels and title
plt.xlabel('X')
plt.ylabel('Density')
plt.title('Continuous Uniform Distribution (a=2, b=8)')
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show plot
plt.show()

# %%
#8.  Simulate data from a normal distribution and plot its histogram
import numpy as np
import matplotlib.pyplot as plt

size=1000
samples = np.random.normal(0, 1, size)

plt.hist(samples, bins=30)
plt.show()

# %%
#9.  Write a Python function to calculate Z-scores from a dataset and plot them

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

def calculate_and_plot_zscores(data):
    mean = np.mean(data)
    std_dev = np.std(data, ddof=1)  # Using sample standard deviation (ddof=1)

    z_scores = (data - mean) / std_dev

    sns.histplot(z_scores, bins=30, kde=True, color='blue', edgecolor='black', alpha=0.7)

    # Labels and title
    plt.xlabel('Z-Score')
    plt.ylabel('Frequency')
    plt.title('Z-Score Distribution')


    # Show plot
    plt.show()

    return z_scores

sample_data = np.random.normal(loc=50, scale=10, size=1000)  # Mean=50, Std=10
z_scores = calculate_and_plot_zscores(sample_data)

# %%
#10.  Implement the Central Limit Theorem (CLT) using Python for a non-normal distribution.
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


population = np.random.random(size=10000)


sample_size = 30
num_samples = 1000

sample_means = [np.mean(np.random.choice(population, size=sample_size)) for _ in range(num_samples)]

# Step 3: Plot the original non-normal distribution
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
sns.histplot(population, bins=50, kde=True, color='blue', alpha=0.7, edgecolor='black')
plt.title('Original Non-Normal Distribution (Exponential)')
plt.xlabel('Value')
plt.ylabel('Frequency')

# Step 4: Plot the distribution of sample means
plt.subplot(1, 2, 2)
sns.histplot(sample_means, bins=30, kde=True, color='green', alpha=0.7, edgecolor='black')
plt.title('Sampling Distribution of the Mean (CLT)')
plt.xlabel('Sample Mean')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
#11.  Simulate multiple samples from a normal distribution and verify the Central Limit Theorem
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


mu, sigma = 50, 10  # Mean and Standard Deviation
population = np.random.normal(mu, sigma, 10000)  # Large normal population

# Step 2: Define sample sizes
sample_sizes = [5, 30, 100]  # Small, medium, and large sample sizes
num_samples = 1000  # Number of samples

# Step 3: Compute sample means for each sample size
sample_means = {
    n: [np.mean(np.random.choice(population, size=n)) for _ in range(num_samples)]
    for n in sample_sizes
}

# Step 4: Plot the original normal distribution
plt.figure(figsize=(12, 8))

plt.subplot(2, 2, 1)
sns.histplot(population, bins=50, kde=True, color='blue', alpha=0.7, edgecolor='black')
plt.title('Original Normal Distribution')
plt.xlabel('Value')
plt.ylabel('Frequency')

# Step 5: Plot the sampling distributions for different sample sizes
for i, n in enumerate(sample_sizes, start=2):
    plt.subplot(2, 2, i)
    sns.histplot(sample_means[n], bins=30, kde=True, color='green', alpha=0.7, edgecolor='black')
    plt.title(f'Sampling Distribution (n={n})')
    plt.xlabel('Sample Mean')
    plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
#12. Write a Python function to calculate and plot the standard normal distribution (mean = 0, std = 1)
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

def plot_standard_normal():
    x = np.linspace(-4, 4, 1000)

    # Compute the PDF of the standard normal distribution
    y = stats.norm.pdf(x, loc=0, scale=1)

    # Plot the standard normal curve
    plt.figure(figsize=(8, 5))
    plt.plot(x, y, label='Standard Normal Distribution', color='blue')

    # Add mean and standard deviations
    plt.axvline(0, color='red', linestyle='dashed', label='Mean (μ = 0)')
    plt.axvline(-1, color='green', linestyle='dashed', alpha=0.7, label='1σ')
    plt.axvline(1, color='green', linestyle='dashed', alpha=0.7)
    plt.axvline(-2, color='orange', linestyle='dashed', alpha=0.7, label='2σ')
    plt.axvline(2, color='orange', linestyle='dashed', alpha=0.7)
    plt.axvline(-3, color='purple', linestyle='dashed', alpha=0.7, label='3σ')
    plt.axvline(3, color='purple', linestyle='dashed', alpha=0.7)

    # Labels and title
    plt.xlabel('Z-Score')
    plt.ylabel('Probability Density')
    plt.title('Standard Normal Distribution (μ=0, σ=1)')
    plt.legend()
    plt.grid(True)

    # Show plot
    plt.show()

# Call the function to plot
plot_standard_normal()

# %%
#13. Generate random variables and calculate their corresponding probabilities using the binomial distribution
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats


n = 10
p = 0.5


random_variables = np.random.binomial(n, p, 1000)  # 1000 samples from Binomial(n, p)


x = np.arange(0, n + 1)  # Possible values (0 to n)
pmf_values = stats.binom.pmf(x, n, p)  # Compute PMF

plt.figure(figsize=(10, 5))


plt.subplot(1, 2, 1)
plt.hist(random_variables, bins=np.arange(n+2)-0.5, density=True, color='blue', alpha=0.6, edgecolor='black')
plt.xlabel('Number of Successes (k)')
plt.ylabel('Frequency')
plt.title('Histogram of Generated Binomial Random Variables')


plt.subplot(1, 2, 2)
plt.bar(x, pmf_values, color='green', alpha=0.7, edgecolor='black')
plt.xlabel('Number of Successes (k)')
plt.ylabel('Probability')
plt.title('Binomial Probability Mass Function (PMF)')

plt.tight_layout()
plt.show()

# %%
#14. Write a Python program to calculate the Z-score for a given data point and compare it to a standard normal distribution
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

def calculate_z_score(data, x):

    mean = np.mean(data)
    std_dev = np.std(data, ddof=1)
    z_score = (x - mean) / std_dev
    return z_score


data = np.random.normal(loc=50, scale=10, size=1000)  # Mean = 50, Std Dev = 10, 1000 data points


x_value = 65  # Example
z_value = calculate_z_score(data, x_value)
print(f"Data point: {x_value}, Z-score: {z_value:.2f}")


x = np.linspace(-4, 4, 1000)
y = stats.norm.pdf(x, 0, 1)

plt.figure(figsize=(8, 5))
plt.plot(x, y, label='Standard Normal Distribution', color='blue')

# Mark the Z-score position
plt.axvline(z_value, color='red', linestyle='dashed', label=f'Z-score = {z_value:.2f}')


x_fill = np.linspace(-4, z_value, 500)
y_fill = stats.norm.pdf(x_fill, 0, 1)
plt.fill_between(x_fill, y_fill, color='green', alpha=0.3)

# Labels and legend
plt.xlabel('Z-Score')
plt.ylabel('Probability Density')
plt.title('Z-Score Comparison with Standard Normal Distribution')
plt.legend()
plt.grid(True)

plt.show()
# Out:
# Data point: 65, Z-score: 1.48

# %%
#15. 5 Implement hypothesis testing using Z-statistics for a sample dataset
import numpy as np
import scipy.stats as stats

def z_test(sample, pop_mean, pop_std, alpha=0.05):

    n = len(sample)
    sample_mean = np.mean(sample)
    se = pop_std / np.sqrt(n)


    z_score = (sample_mean - pop_mean) / se

    # Compute p-value for a two-tailed test
    p_value = 2 * (1 - stats.norm.cdf(abs(z_score)))


    reject_null = p_value < alpha

    return z_score, p_value, reject_null



sample_data = np.random.normal(loc=172, scale=6, size=50)  # Mean=172, Std=6, Sample size=50


population_mean = 170  # Null hypothesis mean
population_std = 6  # Known population standard deviation

# Step 3: Perform Z-test
z_score, p_value, reject_null = z_test(sample_data, population_mean, population_std)

# Step 4: Display results
print(f"Z-Score: {z_score:.3f}")
print(f"P-Value: {p_value:.5f}")
if reject_null:
    print("Conclusion: Reject the null hypothesis (H0).")
else:
    print("Conclusion: Fail to reject the null hypothesis (H0).")
# Out:
# Z-Score: 0.763
# P-Value: 0.44565
# Conclusion: Fail to reject the null hypothesis (H0).

# %%
#16. Create a confidence interval for a dataset using Python and interpret the result
import numpy as np
import scipy.stats as stats

def confidence_interval(data, confidence=0.95):

    n = len(data)
    sample_mean = np.mean(data)
    sample_std = np.std(data, ddof=1)


    se = sample_std / np.sqrt(n)
    z_score = stats.norm.ppf(1 - (1 - confidence) / 2)

    # Compute confidence interval bounds
    margin_of_error = z_score * se
    lower_bound = sample_mean - margin_of_error
    upper_bound = sample_mean + margin_of_error

    return lower_bound, upper_bound, sample_mean



sample_data = np.random.normal(loc=75, scale=10, size=50)  # Mean=75, Std=10, Sample size=50


lower, upper, mean = confidence_interval(sample_data, confidence=0.95)


print(f"Sample Mean: {mean:.2f}")
print(f"95% Confidence Interval: ({lower:.2f}, {upper:.2f})")
# Out:
# Sample Mean: 75.18
# 95% Confidence Interval: (72.75, 77.60)

# %%
#17. Generate data from a normal distribution, then calculate and interpret the confidence interval for its mean
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

def confidence_interval(data, confidence=0.95):

    n = len(data)
    sample_mean = np.mean(data)
    sample_std = np.std(data, ddof=1)


    se = sample_std / np.sqrt(n)


    z_score = stats.norm.ppf(1 - (1 - confidence) / 2)


    margin_of_error = z_score * se
    lower_bound = sample_mean - margin_of_error
    upper_bound = sample_mean + margin_of_error

    return lower_bound, upper_bound, sample_mean



sample_data = np.random.normal(loc=100, scale=15, size=50)
lower, upper, mean = confidence_interval(sample_data, confidence=0.95)


print(f"Sample Mean: {mean:.2f}")
print(f"95% Confidence Interval: ({lower:.2f}, {upper:.2f})")


plt.figure(figsize=(8, 5))
plt.hist(sample_data, bins=10, color='skyblue', edgecolor='black', alpha=0.7, density=True, label='Sample Data')

# Mark mean and confidence interval bounds
plt.axvline(mean, color='red', linestyle='dashed', linewidth=2, label=f'Mean = {mean:.2f}')
plt.axvline(lower, color='green', linestyle='dashed', linewidth=2, label=f'Lower CI = {lower:.2f}')
plt.axvline(upper, color='green', linestyle='dashed', linewidth=2, label=f'Upper CI = {upper:.2f}')

# Labels and legend
plt.xlabel('Value')
plt.ylabel('Density')
plt.title('Histogram of Sample Data with 95% Confidence Interval')
plt.legend()
plt.grid(True)

plt.show()
# Out:
# Sample Mean: 99.41
# 95% Confidence Interval: (95.19, 103.63)

# %%
#18. Write a Python script to calculate and visualize the probability density function (PDF) of a normal distribution
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# Step 1: Define parameters
mu = 0      # Mean
sigma = 1   # Standard deviation

# Step 2: Generate x values
x = np.linspace(mu - 4*sigma, mu + 4*sigma, 1000)  # Covering a wide range around mean

# Step 3: Calculate the PDF using scipy
pdf_values = stats.norm.pdf(x, mu, sigma)

# Step 4: Plot the PDF
plt.figure(figsize=(8, 5))
plt.plot(x, pdf_values, color='blue', linewidth=2, label='Normal PDF (μ=0, σ=1)')

# Step 5: Add mean and standard deviation markers
plt.axvline(mu, color='red', linestyle='dashed', linewidth=2, label='Mean (μ)')
plt.axvline(mu - sigma, color='green', linestyle='dashed', linewidth=1, label='1 Std Dev (μ - σ)')
plt.axvline(mu + sigma, color='green', linestyle='dashed', linewidth=1, label='1 Std Dev (μ + σ)')

# Labels and legend
plt.xlabel('X')
plt.ylabel('Probability Density')
plt.title('Probability Density Function (PDF) of a Normal Distribution')
plt.legend()
plt.grid(True)

# Step 6: Show the plot
plt.show()

# %%
#19.  Use Python to calculate and interpret the cumulative distribution function (CDF) of a Poisson distribution
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt


lambda_val = 5


x = np.arange(0, 16)


cdf_values = stats.poisson.cdf(x, lambda_val)


plt.figure(figsize=(8, 5))
plt.step(x, cdf_values, where='mid', color='blue', linewidth=2, label=f'Poisson CDF (λ={lambda_val})')

plt.xlabel('Number of Events (x)')
plt.ylabel('Cumulative Probability')
plt.title('Cumulative Distribution Function (CDF) of a Poisson Distribution')
plt.grid(True)
plt.legend()


plt.show()


prob_3_or_less = cdf_values[3]  # P(X ≤ 3)
print(f"Probability of observing 3 or fewer events (P(X ≤ 3)): {prob_3_or_less:.4f}")
# Out:
# Probability of observing 3 or fewer events (P(X ≤ 3)): 0.2650

# %%
#20. Simulate a random variable using a continuous uniform distribution and calculate its expected value
import numpy as np
import matplotlib.pyplot as plt


a, b = 2, 10


num_samples = 10000
uniform_samples = np.random.uniform(a, b, num_samples)


expected_value_theoretical = (a + b) / 2
expected_value_empirical = np.mean(uniform_samples)


plt.figure(figsize=(8, 5))
plt.hist(uniform_samples, bins=30, density=True, color='skyblue', edgecolor='black', alpha=0.7, label="Simulated Data")


plt.axvline(expected_value_theoretical, color='red', linestyle='dashed', linewidth=2, label=f'Theoretical Mean = {expected_value_theoretical:.2f}')
plt.axvline(expected_value_empirical, color='green', linestyle='dashed', linewidth=2, label=f'Empirical Mean = {expected_value_empirical:.2f}')


plt.xlabel('Value')
plt.ylabel('Density')
plt.title('Histogram of Uniformly Distributed Random Variable')
plt.legend()
plt.grid(True)


plt.show()


print(f"Theoretical Expected Value: {expected_value_theoretical:.2f}")
print(f"Empirical Expected Value (from simulation): {expected_value_empirical:.2f}")
# Out:
# Theoretical Expected Value: 6.00
# Empirical Expected Value (from simulation): 5.96

# %%
#21. Write a Python program to compare the standard deviations of two datasets and visualize the difference5
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(42)
dataset1 = np.random.normal(loc=50, scale=10, size=1000)  # Mean=50, Std=10
dataset2 = np.random.normal(loc=50, scale=20, size=1000)  # Mean=50, Std=20


std1 = np.std(dataset1, ddof=1)
std2 = np.std(dataset2, ddof=1)


plt.figure(figsize=(8, 5))
plt.hist(dataset1, bins=30, alpha=0.6, color='blue', label=f"Dataset 1 (σ={std1:.2f})")
plt.hist(dataset2, bins=30, alpha=0.6, color='red', label=f"Dataset 2 (σ={std2:.2f})")


plt.xlabel("Value")
plt.ylabel("Frequency")
plt.title("Comparison of Standard Deviations in Two Datasets")
plt.legend()
plt.grid(True)


plt.show()


print(f"Standard Deviation of Dataset 1: {std1:.2f}")
print(f"Standard Deviation of Dataset 2: {std2:.2f}")
# Out:
# Standard Deviation of Dataset 1: 9.79
# Standard Deviation of Dataset 2: 19.95

# %%
#22.  Calculate the range and interquartile range (IQR) of a dataset generated from a normal distribution
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

np.random.seed(42)
data = np.random.normal(loc=50, scale=15, size=1000)


data_range = np.max(data) - np.min(data)


Q1 = np.percentile(data, 25)
Q3 = np.percentile(data, 75)
IQR = Q3 - Q1


plt.figure(figsize=(8, 5))
sns.histplot(data, bins=30, kde=True, color='skyblue', label="Data Distribution")


plt.axvline(Q1, color='green', linestyle='dashed', linewidth=2, label=f'Q1 (25th) = {Q1:.2f}')
plt.axvline(Q3, color='red', linestyle='dashed', linewidth=2, label=f'Q3 (75th) = {Q3:.2f}')
plt.axvline(np.min(data), color='black', linestyle='dashed', linewidth=1, label=f'Min = {np.min(data):.2f}')
plt.axvline(np.max(data), color='black', linestyle='dashed', linewidth=1, label=f'Max = {np.max(data):.2f}')


plt.xlabel("Value")
plt.ylabel("Frequency")
plt.title("Normal Distribution with Range and IQR")
plt.legend()
plt.grid(True)


plt.show()


print(f"Range: {data_range:.2f}")
print(f"Interquartile Range (IQR): {IQR:.2f}")
# Out:
# Range: 106.41
# Interquartile Range (IQR): 19.43

# %%
#23. Implement Z-score normalization on a dataset and visualize its transformation

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


data = np.random.normal(loc=50, scale=15, size=1000)


mean = np.mean(data)
std_dev = np.std(data, ddof=1)


z_scores = (data - mean) / std_dev


plt.figure(figsize=(10, 5))


plt.subplot(1, 2, 1)
sns.histplot(data, bins=30, kde=True, color='skyblue', label="Original Data")
plt.axvline(mean, color='red', linestyle='dashed', linewidth=2, label=f'Mean = {mean:.2f}')
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.title("Original Distribution")
plt.legend()
plt.grid(True)


plt.subplot(1, 2, 2)
sns.histplot(z_scores, bins=30, kde=True, color='orange', label="Z-Score Normalized Data")
plt.axvline(0, color='red', linestyle='dashed', linewidth=2, label='Mean = 0')
plt.xlabel("Z-Score")
plt.ylabel("Frequency")
plt.title("Z-Score Normalized Distribution")
plt.legend()
plt.grid(True)


plt.tight_layout()
plt.show()


print(f"Original Mean: {mean:.2f}, Original Std Dev: {std_dev:.2f}")
print(f"Normalized Mean: {np.mean(z_scores):.2f}, Normalized Std Dev: {np.std(z_scores, ddof=1):.2f}")
# Out:
# Original Mean: 51.06, Original Std Dev: 14.96
# Normalized Mean: -0.00, Normalized Std Dev: 1.00

# %%
#24. Write a Python function to calculate the skewness and kurtosis of a dataset generated from a normal distribution.

import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns

def analyze_distribution(data):

    skewness = stats.skew(data)
    kurtosis = stats.kurtosis(data, fisher=True)


    plt.figure(figsize=(8, 5))
    sns.histplot(data, bins=30, kde=True, color='skyblue', label="Data Distribution")


    plt.xlabel("Value")
    plt.ylabel("Frequency")
    plt.title(f"Skewness: {skewness:.2f}, Kurtosis: {kurtosis:.2f}")
    plt.axvline(np.mean(data), color='red', linestyle='dashed', linewidth=2, label=f'Mean = {np.mean(data):.2f}')
    plt.legend()
    plt.grid(True)


    plt.show()


    return skewness, kurtosis


np.random.seed(42)
data = np.random.normal(loc=50, scale=15, size=1000)


skew, kurt = analyze_distribution(data)


print(f"Skewness: {skew:.2f}")
print(f"Kurtosis (Excess): {kurt:.2f}")
# Out:
# Skewness: 0.12
# Kurtosis (Excess): 0.07
