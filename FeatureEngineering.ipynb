# %% [markdown]
# #Feature Engineering
# ##Assignment Questions
#
# 1. What is a parameter?
#   - A parameter is an input variable passed to a function or method to customize its behavior.
#
# 2.What is correlation? What does negative correlation mean?
#   - Correlation is a statistical measure that describes the strength and direction of a relationship between two variables. It tells us how changes in one variable are associated with changes in another.
#   - A negative correlation means that as one variable increases, the other decreases.
#
# 3. Define Machine Learning. What are the main components in Machine Learning?
#   - Machine learning is basically understanding the pattern in the dataset.It gives computer ability to learn without explicitly programmed.
#     - Main Components:
#       - Data
#       - Model(Built with relevant Algorithm)
#       - Training
#       -Testing
#       -Validating
#
# 4. How does loss value help in determining whether the model is good or not?
#   - The loss value is a numerical measure of how well a machine learning model is performing. It represents the difference between the model’s predictions and the actual values (ground truth). Lower loss values indicate a better model, while higher values suggest poor predictions.
#
# 5. What are continuous and categorical variables?
#   - Continuous variables: It takes all the value on the number line. All the real numbers as their value.
#   - Categorical Variables: It takes the value in the formate of string.
#
# 6. How do we handle categorical variables in Machine Learning? What are the common techniques?
#   - We need to convert categorical variables into numerical form.
#   -i. Nominal/One Hot Encoding
#   -ii. Label and Ordinal Encoding
#   -iii. Target Guided Ordinal Encoding.
#
# 7. What do you mean by training and testing a dataset?
#   - Training dataset: It is used to train our ML model to identify the pattern to form the Mathematical Function.
#   -Testing Dataset: It is used to test the performance and accuracy of the model. It is basically the unseen data for the model.
#
# 8. What is sklearn.preprocessing?
#   - sklearn.preprocessing is a module in Scikit-learn that provides tools for scaling, normalizing, encoding, and transforming data. These transformations help improve the performance of machine learning models by making the data suitable for algorithms.
#
# 9. What is a Test set?
#   - A test set is a subset of the dataset used to evaluate the performance of a trained machine learning model. It contains data that the model has never seen before, helping to assess how well the model generalizes to new data.
#
# 10. How do we split data for model fitting (training and testing) in Python? How do you approach a Machine Learning problem?
#   - Training Dataset - Around 80 percent of the dataset.
#   - Testing Dataset - Around 20 percent of the dataset.
#
#
# 11. Why do we have to perform EDA before fitting a model to the data?
#   - Exploratory Data Analysis (EDA) is a crucial step in machine learning that helps understand the dataset before training a model. It involves visualizing, summarizing, and detecting patterns or issues in the data.
#
# 12. What is correlation?
#   - Strengt and Direction of two variables.
#   -Correlation is a statistical measure that describes the strength and direction of a relationship between two variables. It tells us how changes in one variable are associated with changes in another.
#
# 13. What does negative correlation mean?
#   - A negative correlation means that as one variable increases, the other decreases.
#
# 14. How can you find correlation between variables in Python?
#   - In Python, we can find correlation using Pandas [.corr()], NumPy [.corrcoef()], and Seaborn[.corr()].
#
# 15. What is causation? Explain difference between correlation and causation with an example.
#   - Causation (or causality) means that one variable directly influences another variable. If X causes Y, then changing X directly affects Y.
#   - Here only One variable influences the other variable.
#
# 16. What is an Optimizer? What are different types of optimizers? Explain each with an example.
#   - An optimizer is an algorithm used in machine learning and deep learning to adjust the model’s parameters (weights and biases) to minimize the loss function and improve accuracy. It helps in efficiently finding the optimal set of weights during training.
#   - Gradient Descent (GD)
#   - Adaptive Optimizers
#   -  RMSprop (Root Mean Square Propagation)
#
# 17. What is sklearn.linear_model ?
#   - sklearn.linear_model is a module in Scikit-Learn that provides linear models for regression and classification tasks. These models assume a linear relationship between input features and the target variable.
#
# 18. What does model.fit() do? What arguments must be given?
#   - model.fit() is a method used in Scikit-Learn to train a machine learning model on a given dataset. It learns the relationship between input features (X) and target labels (y) by adjusting model parameters.
#   - Arguments are >> Input variables,target Variable.
#
# 19. What does model.predict() do? What arguments must be given?
#   -model.predict() is used after training a machine learning model with model.fit(). It takes new input data and returns the model’s predicted outputs based on the learned patterns.
#
# 20. What are continuous and categorical variables?
#   - Continuous variables: It takes all the value on the number line. All the real numbers as their value.
#   - Categorical Variables: It takes the value in the formate of string.
#
# 21. What is feature scaling? How does it help in Machine Learning?
#   - Feature Scaling is basically bringing the units of Features to same scale.
#   - It helps in comparing the features.
#   - Learning pattern on smaller magnitude od scale is easier than comparing pattern with larger pattern.
#
# 22. How do we perform scaling in Python?
#   - Scaling is used in machine learning to normalize or standardize features so that they have a consistent range or distribution. This improves model performance, especially for algorithms sensitive to feature magnitudes.
#   -That can be implemented with sklearn.preprocessing library.
#
# 23. What is sklearn.preprocessing?
#   - It is used for scaling fratures in ML.
#
# 24. How do we split data for model fitting (training and testing) in Python?
#   - Training Dataset - Around 80 percent of the dataset.
#   - Testing Dataset - Around 20 percent of the dataset.
#
# 25. Explain data encoding?
#   -It is the process of converting categorical(string) data to the numeric data so the ML algorithm can understand and process the information.
